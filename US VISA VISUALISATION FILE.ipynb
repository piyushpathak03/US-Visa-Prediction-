# %% [markdown]
# # US PERM VISAS DATASET

# %% [markdown]
# ### Importing all the required libraries to load and visualise the dataset

# %%
from pyforest import *
import pandas_profiling as pp
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the dataset

# %%
a=pd.read_excel("edited final.xlsx")

# %% [markdown]
# ### Visualising data using pandas profiling

# %%
pp.ProfileReport(a)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %% [markdown]
# ## Checking the shape of dataset

# %%
a.shape
# Out:
# (374362, 26)

# %% [markdown]
# ### We are having 374362 rows and 26 columns in our datset

# %% [markdown]
# ## Checking the types of data in our dataset

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Data columns (total 26 columns):
# agent_state                      208239 non-null object
# application_type                 135269 non-null object
# case_no                          135269 non-null object
# case_received_date               239091 non-null datetime64[ns]
# case_status                      374362 non-null object
# class_of_admission               351517 non-null object
# country_of_citizenship           374302 non-null object
# decision_date                    374362 non-null datetime64[ns]
# employer_num_employees           239013 non-null float64
# employer_yr_estab                238958 non-null float64
# employer_city                    374348 non-null object
# employer_name                    374350 non-null object
# employer_state                   374320 non-null object
# foreign_worker_info_education    239053 non-null object
# ...

# %% [markdown]
# #### We are having almost all the features as object class or float.

# %% [markdown]
# ## Checking the five point summary of our dataset

# %%
a.describe()
# Out:
#        employer_num_employees  employer_yr_estab  previous_salary
# count            2.390130e+05      238958.000000     3.721460e+05
# mean             2.309387e+04        1984.208267     8.535016e+04
# std              5.453129e+05          38.470555     8.685850e+04
# min              0.000000e+00           0.000000     5.550000e+00
# 25%              7.300000e+01        1980.000000     6.643500e+04
# 50%              1.200000e+03        1996.000000     8.567500e+04
# 75%              1.613400e+04        2004.000000     1.044160e+05
# max              2.635506e+08        2016.000000     1.352832e+07

# %% [markdown]
# ### We are having 23 categorical columns and 3 numerical columns

# %% [markdown]
# ## Checking the head (first 5 rows) of the dataset)

# %%
a.head()
# Out:
#   agent_state application_type        case_no case_received_date case_status  \
# 0         NaN             PERM  A-07323-97014                NaT   Certified
# 1         NaN             PERM  A-07332-99439                NaT      Denied
# 2         NaN             PERM  A-07333-99643                NaT   Certified
# 3         NaN             PERM  A-07339-01930                NaT   Certified
# 4         NaN             PERM  A-07345-03565                NaT   Certified
#
#   class_of_admission country_of_citizenship decision_date  \
# 0                J-1                ARMENIA    2012-02-01
# 1                B-2                 POLAND    2011-12-21
# 2               H-1B                  INDIA    2011-12-01
# 3                B-2            SOUTH KOREA    2011-12-01
# 4                L-1                 CANADA    2012-01-26
#
#    employer_num_employees  employer_yr_estab  ... job_title job_training  \
# 0                     NaN                NaN  ...       NaN          NaN
# ...

# %% [markdown]
# ## Checking the null values in our dataset

# %%
a.isnull().sum().sum()
# Out:
# 2287544

# %%
a[a.duplicated()].sum()
# Out:
# employer_num_employees    1.597250e+08
# employer_yr_estab         1.736881e+07
# previous_salary           4.611263e+08
# dtype: float64

# %%
a.isnull().sum()
# Out:
# agent_state                      166123
# application_type                 239093
# case_no                          239093
# case_received_date               135271
# case_status                           0
# class_of_admission                22845
# country_of_citizenship               60
# decision_date                         0
# employer_num_employees           135349
# employer_yr_estab                135404
# employer_city                        14
# employer_name                        12
# employer_state                       42
# foreign_worker_info_education    135309
# foreign_worker_info_major        154972
# job_experience                   135281
# job_title                        135313
# job_training                     135284
# job_work_state                      103
# pv_unit_of_pay_9089               10053
# previous_salary                    2216
# level                             27627
# source_name                        2099
# ...

# %% [markdown]
# ### we are having null values in 24 columns except decision date and case status

# %% [markdown]
# # Checking the percentage of null values in our dataset

# %%
a.isnull().sum()*100/374362     # percentage values
# Out:
# agent_state                      44.374963
# application_type                 63.866792
# case_no                          63.866792
# case_received_date               36.133742
# case_status                       0.000000
# class_of_admission                6.102382
# country_of_citizenship            0.016027
# decision_date                     0.000000
# employer_num_employees           36.154578
# employer_yr_estab                36.169269
# employer_city                     0.003740
# employer_name                     0.003205
# employer_state                    0.011219
# foreign_worker_info_education    36.143893
# foreign_worker_info_major        41.396296
# job_experience                   36.136413
# job_title                        36.144961
# job_training                     36.137215
# job_work_state                    0.027513
# pv_unit_of_pay_9089               2.685369
# previous_salary                   0.591940
# level                             7.379755
# ...

# %% [markdown]
# ### We are having more than 30% null values in almost 14 columns and less than 10% in rest 10 columns

# %% [markdown]
# # Displaying the columns names to understand features

# %%
a.columns    # 26 columns initially in dataset
# Out:
# Index(['agent_state', 'application_type', 'case_no', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        'decision_date', 'employer_num_employees', 'employer_yr_estab',
#        'employer_city', 'employer_name', 'employer_state',
#        'foreign_worker_info_education', 'foreign_worker_info_major',
#        'job_experience', 'job_title', 'job_training', 'job_work_state',
#        'pv_unit_of_pay_9089', 'previous_salary', 'level', 'source_name',
#        'sector', 'wage_offer', 'wage_unit_of_pay'],
#       dtype='object')

# %% [markdown]
# ## `To check the duplicates rows in our dataset`

# %%
a[a.duplicated()==True]
# Out:
#            agent_state application_type case_no case_received_date  \
# 135273  NORTH CAROLINA              NaN     NaN         2013-11-12
# 135277  NORTH CAROLINA              NaN     NaN         2013-11-12
# 135278  NORTH CAROLINA              NaN     NaN         2013-11-12
# 135284  NORTH CAROLINA              NaN     NaN         2013-11-12
# 135301  NORTH CAROLINA              NaN     NaN         2013-11-11
# 135305             NaN              NaN     NaN         2013-11-13
# 135312  NORTH CAROLINA              NaN     NaN         2013-11-11
# 135326  NORTH CAROLINA              NaN     NaN         2013-11-11
# 135330  NORTH CAROLINA              NaN     NaN         2013-11-12
# 135343  NORTH CAROLINA              NaN     NaN         2013-11-11
# 135362             NaN              NaN     NaN         2013-11-14
# 135373  NORTH CAROLINA              NaN     NaN         2013-11-11
# 135387             NaN              NaN     NaN         2013-11-13
# ...

# %% [markdown]
# ### We are having 8375 duplicates rows in our datset.

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# # `Feature 1`
# ### Agent_state  =  44.374963% missing values

# %%
a.agent_state.unique()
# Out:
# array([nan, 'WISCONSIN', 'NORTH CAROLINA', 'COLORADO', 'CALIFORNIA',
#        'MICHIGAN', 'NEW YORK', 'TEXAS', 'PENNSYLVANIA', 'NEW JERSEY',
#        'MISSOURI', 'FLORIDA', 'VIRGINIA', 'OHIO', 'DISTRICT OF COLUMBIA',
#        'INDIANA', 'GEORGIA', 'MASSACHUSETTS', 'ILLINOIS', 'ALABAMA',
#        'OKLAHOMA', 'WASHINGTON', 'CONNECTICUT', 'MINNESOTA', 'ARKANSAS',
#        'HAWAII', 'MARYLAND', 'UTAH', 'PUERTO RICO', 'ARIZONA', 'NEVADA',
#        'NEW HAMPSHIRE', 'OREGON', 'KANSAS', 'NEW MEXICO', 'VERMONT',
#        'TENNESSEE', 'NEBRASKA', 'LOUISIANA', 'KENTUCKY', 'GUAM', 'IOWA',
#        'SOUTH CAROLINA', 'RHODE ISLAND', 'MAINE', 'IDAHO', 'NORTH DAKOTA',
#        'ALASKA', 'MISSISSIPPI', 'DELAWARE', 'MARSHALL ISLANDS',
#        'SOUTH DAKOTA', 'MONTANA', 'WEST VIRGINIA', 'NE', 'FL', 'TX', 'CA',
#        'NY', 'GA', 'MA', 'DC', 'IL', 'VA', 'NC', 'MD', 'TN', 'LA', 'NJ',
#        'HI', 'PA', 'MI', 'MO', 'WI', 'OK', 'AZ', 'OR', 'MN', 'OH', 'CT',
# ...

# %%
a.agent_state.nunique()      # 108 states from where agents applying
# Out:
# 108

# %% [markdown]
# ### We are having total 108 agent states  and few having short abbreviation for the respective countries name.

# %% [markdown]
# # `Feature 2`
# ###  Application_type  = 63.866792 % missing values

# %%
a.application_type.unique()     # 3 types of applications
# Out:
# array(['PERM', 'ONLINE', 'MAILEDIN', nan], dtype=object)

# %%
a.application_type.value_counts(normalize=True)
# Out:
# ONLINE      0.832149
# PERM        0.152112
# MAILEDIN    0.015739
# Name: application_type, dtype: float64

# %%
a.application_type.value_counts().plot(kind='bar')         
plt.show()

# %% [markdown]
# ### We are having 3 types of application types:
#      1.Online
#      2.Perm
#      3.Mailed in
#
# ### Online type of application have the maximum count as compared to Perm and Mailedin.

# %% [markdown]
# # `Feature 3`
# ### Case_no = 63.866792 % missing values

# %%
a.case_no.unique()
# Out:
# array(['A-07323-97014', 'A-07332-99439', 'A-07333-99643', ...,
#        'A-14267-09766', 'A-14086-56170', nan], dtype=object)

# %%
a.case_no.nunique() ### case_no are almost unique as it is an unique id in which first 2 characters represent the case received year
# Out:
# 134990

# %% [markdown]
# ### We are having 134990 unique case no allotted to applicants in our dataset.

# %% [markdown]
# # `Feature 4`
# ### Case_received_date = 36.133742 % missing values

# %%
a.case_received_date.unique()
# Out:
# array([                          'NaT', '2013-11-19T00:00:00.000000000',
#        '2013-11-12T00:00:00.000000000', ...,
#        '2016-12-28T00:00:00.000000000', '2016-12-29T00:00:00.000000000',
#        '2016-12-30T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
a.case_received_date.nunique()
# Out:
# 2180

# %%
a.case_received_date.value_counts().head(15)
# Out:
# 2014-06-30    767
# 2015-09-30    696
# 2015-06-30    695
# 2015-06-29    691
# 2016-06-29    670
# 2015-09-29    649
# 2016-06-30    634
# 2014-06-27    555
# 2016-04-29    544
# 2015-07-17    515
# 2015-07-30    512
# 2014-12-19    511
# 2016-06-28    509
# 2016-04-28    503
# 2016-04-15    500
# Name: case_received_date, dtype: int64

# %%
a.case_received_date.isnull().sum()
# Out:
# 135271

# %% [markdown]
# ### We are having 135271 unique case received date when case have been applied or signed.

# %% [markdown]
# # `Feature 5 = Target Variable`
# ## case_status

# %%
a.case_status.value_counts(normalize=True)
# value counts in percentile
# Out:
# Certified            0.485981
# Certified-Expired    0.396905
# Denied               0.068514
# Withdrawn            0.048600
# Name: case_status, dtype: float64

# %%
a.case_status.value_counts().plot(kind="bar")

# %% [markdown]
# ### There are 4 categories of case status:
#     1. Certified            48%
#     2. Certified-Expired    40%
#     3. Denied               6%
#     4. Withdrawn            4%
#
# ### We are having maximum certified and certified-withdrawn cases as less counts for withdrwan and denied cases.

# %% [markdown]
# # `Feature 6`
# ### class_of_admission = 6.102382 % null values

# %%
a.class_of_admission.unique()
# Out:
# array(['J-1', 'B-2', 'H-1B', 'L-1', 'EWI', 'E-2', nan, 'E-1', 'H-2B',
#        'TPS', 'F-1', 'B-1', 'C-1', 'Not in USA', 'TN', 'H-4', 'O-1',
#        'R-1', 'L-2', 'Q', 'F-2', 'H-1B1', 'Parolee', 'G-5', 'E-3', 'H-2A',
#        'VWT', 'P-1', 'A1/A2', 'D-1', 'A-3', 'R-2', 'H-1C', 'H-3', 'J-2',
#        'P-4', 'I', 'H-1A', 'G-1', 'VWB', 'G-4', 'P-3', 'AOS/H-1B', 'O-3',
#        'Parol', 'O-2', 'H1B', 'N', 'T-1', 'TD', 'M-1', 'K-1', 'U-1',
#        'AOS', 'P-2', 'C-3', 'V-2', 'M-2'], dtype=object)

# %%
a.class_of_admission.value_counts(normalize=True).head(15)
# Out:
# H-1B          0.805133
# L-1           0.056720
# F-1           0.042519
# Not in USA    0.024431
# TN            0.012133
# E-2           0.012053
# B-2           0.009482
# Parolee       0.007618
# EWI           0.005562
# J-1           0.002740
# F-2           0.002731
# E-3           0.002498
# O-1           0.002290
# H-4           0.002102
# B-1           0.001764
# Name: class_of_admission, dtype: float64

# %%
plt.figure(figsize=(15,11))
a.class_of_admission.value_counts(normalize=True).plot(kind='bar',color='magenta')
plt.show()

# %%
a.class_of_admission.value_counts(normalize=True)[a.class_of_admission.value_counts(normalize=True)>0.002].plot(kind='bar',color='green')
plt.show()

# %% [markdown]
# ###  H1-b visa having maximum counts ie 81% applicants applied for H1-b visa.

# %% [markdown]
# # `Feauture 7`
# ## country_of_citizenship = 0.016027 % missing values

# %%
a.country_of_citizenship.nunique()
# Out:
# 202

# %%
a.country_of_citizenship.unique()    # 202 countries
# Out:
# array(['ARMENIA', 'POLAND', 'INDIA', 'SOUTH KOREA', 'CANADA', 'ECUADOR',
#        'MEXICO', 'PAKISTAN', 'SINGAPORE', 'RUSSIA', 'VENEZUELA', 'JAPAN',
#        'SOUTH AFRICA', 'CHINA', 'PHILIPPINES', 'TURKEY', 'VIETNAM',
#        'EL SALVADOR', 'IRAN', 'CAMEROON', 'JAMAICA', 'INDONESIA',
#        'SWEDEN', 'PORTUGAL', 'COLOMBIA', 'BRAZIL', 'TRINIDAD AND TOBAGO',
#        'GUATEMALA', 'BANGLADESH', 'MONGOLIA', 'SPAIN', 'MOROCCO',
#        'UNITED STATES OF AMERICA', 'NIGERIA', 'BOLIVIA', 'AUSTRIA',
#        'ISRAEL', 'ITALY', 'ARGENTINA', 'IRELAND', 'BULGARIA', 'EGYPT',
#        'TAIWAN', 'UNITED KINGDOM', 'SLOVAKIA', 'DOMINICAN REPUBLIC',
#        'NEPAL', 'KENYA', 'ROMANIA', 'MALAYSIA', 'UNITED ARAB EMIRATES',
#        'SRI LANKA', 'PERU', 'FRANCE', 'UKRAINE', 'HUNGARY', 'MACEDONIA',
#        'PANAMA', 'PARAGUAY', 'HONG KONG', 'KUWAIT', 'CHILE', 'COSTA RICA',
#        'GERMANY', 'GEORGIA', 'AUSTRALIA', 'MOLDOVA', 'LEBANON',
# ...

# %%
a.country_of_citizenship.value_counts(normalize=True).head(15)
# Out:
# INDIA             0.548108
# CHINA             0.077106
# SOUTH KOREA       0.066152
# CANADA            0.039551
# MEXICO            0.023941
# PHILIPPINES       0.023059
# UNITED KINGDOM    0.013283
# TAIWAN            0.011149
# PAKISTAN          0.010585
# FRANCE            0.008477
# NEPAL             0.008140
# JAPAN             0.007935
# BRAZIL            0.007796
# VENEZUELA         0.007315
# TURKEY            0.006815
# Name: country_of_citizenship, dtype: float64

# %%
a.country_of_citizenship.value_counts(normalize=True)[a.country_of_citizenship.value_counts(normalize=True)>0.008]
# Out:
# INDIA             0.548108
# CHINA             0.077106
# SOUTH KOREA       0.066152
# CANADA            0.039551
# MEXICO            0.023941
# PHILIPPINES       0.023059
# UNITED KINGDOM    0.013283
# TAIWAN            0.011149
# PAKISTAN          0.010585
# FRANCE            0.008477
# NEPAL             0.008140
# Name: country_of_citizenship, dtype: float64

# %%
a.country_of_citizenship.value_counts(normalize=True)[a.country_of_citizenship.value_counts(normalize=True)>0.008].plot(kind='bar')
plt.show()

# %% [markdown]
# ### There are 202 countries of citizenship in our dataset and 54.8% of applications are from India.

# %% [markdown]
# # `Feature 8`
# ## decision_date is having  0  null values

# %%
a.decision_date.nunique()
# Out:
# 1450

# %%
a.decision_date.unique()
# Out:
# array(['2012-02-01T00:00:00.000000000', '2011-12-21T00:00:00.000000000',
#        '2011-12-01T00:00:00.000000000', ...,
#        '2016-12-24T00:00:00.000000000', '2016-12-25T00:00:00.000000000',
#        '2016-12-26T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
a.decision_date.value_counts()
# Out:
# 2015-11-19    1981
# 2015-11-20    1165
# 2015-09-18    1113
# 2015-12-07    1088
# 2015-08-28    1064
# 2016-03-08    1063
# 2015-09-01     977
# 2016-01-26     957
# 2015-07-30     943
# 2016-01-05     942
# 2015-10-15     932
# 2016-06-15     926
# 2016-01-06     917
# 2015-12-08     891
# 2016-01-15     877
# 2016-02-12     838
# 2015-12-09     834
# 2016-01-28     784
# 2016-03-09     763
# 2016-06-20     763
# 2016-08-22     754
# 2015-11-18     738
# 2016-03-23     736
# 2016-09-21     728
# 2016-01-12     727
# 2015-09-21     719
# 2016-07-27     714
# 2016-06-17     709
# 2012-10-16     706
# 2016-01-27     704
#               ...
# 2016-04-09       1
# 2015-10-03       1
# 2012-11-10       1
# 2013-02-23       1
# 2014-09-13       1
# 2011-11-20       1
# 2016-11-06       1
# 2012-12-22       1
# 2015-04-25       1
# 2014-03-09       1
# 2015-03-22       1
# 2013-06-15       1
# 2014-06-28       1
# 2012-02-19       1
# 2015-03-29       1
# 2014-04-19       1
# ...

# %% [markdown]
# ### There are 1450 unique dates on which decision was given for the applications in our dataset.

# %% [markdown]
# # `Feature 9`
# ## employer_city = 0.003740 % null values

# %%
a.employer_city.unique()
# Out:
# array(['NEW YORK', 'CARLSTADT', 'GLEN ALLEN', ..., 'austin',
#        'Carson City', 'Northfield'], dtype=object)

# %%
a.employer_city.nunique()    # 8384 cities
# Out:
# 8384

# %%
a.employer_city.value_counts(normalize=True).head(15)
# Out:
# NEW YORK           0.044691
# COLLEGE STATION    0.032371
# SANTA CLARA        0.029686
# SAN JOSE           0.024974
# REDMOND            0.023518
# MOUNTAIN VIEW      0.022062
# HOUSTON            0.017219
# SUNNYVALE          0.016789
# SAN FRANCISCO      0.016706
# PLANO              0.015590
# CHICAGO            0.015114
# SEATTLE            0.013709
# EDISON             0.011278
# DALLAS             0.010044
# LOS ANGELES        0.009895
# Name: employer_city, dtype: float64

# %%
a.employer_city.value_counts(normalize=True)[a.employer_city.value_counts(normalize=True)>0.01].plot(kind='bar')

# %% [markdown]
# ### We are having 8384 employer cities in our dataset.

# %% [markdown]
# # `Feature 10`
# ## employer_name =  0.003205 % null values

# %%
a.employer_name.unique()
# Out:
# array(['NETSOFT USA INC.', 'PINNACLE ENVIRONEMNTAL CORP',
#        'SCHNABEL ENGINEERING, INC.', ...,
#        'UNION DENTAL GROUP ANAHEIM, INC.', 'AMPHION GLOBAL INC',
#        'Zen Sushi, Inc'], dtype=object)

# %%
a.employer_name.nunique()
# Out:
# 71709

# %% [markdown]
# ### There are 71709 unique names of employers in dataset.

# %% [markdown]
# # `Feature 11`
# ## employer_num_employees = 36.154578 % null values

# %%
a.employer_num_employees.nunique()
# Out:
# 4559

# %%
a.employer_num_employees.unique()
# Out:
# array([   nan,  1935.,   350., ..., 14923.,  3690.,  5221.])

# %%
a.boxplot(column=['employer_num_employees']);      # i.e there are outliers in count of employees in organization

# %%
a.employer_num_employees.value_counts().head(15)
# Out:
# 29000.0    4581
# 35000.0    4417
# 60000.0    3921
# 40000.0    2647
# 5.0        2615
# 3.0        2243
# 10.0       2212
# 46544.0    2146
# 4.0        2096
# 47756.0    1937
# 6.0        1915
# 2.0        1800
# 8.0        1719
# 15.0       1698
# 12.0       1660
# Name: employer_num_employees, dtype: int64

# %% [markdown]
# ### Total of 4559 unique employers_num_employees are present.

# %% [markdown]
# #  `Feature 12`
# # employer_state = 0.011219 % null values

# %%
a.employer_state.unique()
# Out:
# array(['NY', 'VA', 'FL', 'DE', 'MD', 'NJ', 'GA', 'IL', 'TX', 'KY', 'WY',
#        'OH', 'MS', 'MA', 'NC', 'CA', 'MO', 'CT', 'AZ', 'WI', 'PA', 'WA',
#        'CO', 'MN', 'NV', 'UT', 'AL', 'OK', 'LA', 'RI', 'DC', 'OR', 'MI',
#        'IA', 'NH', 'IN', 'SD', nan, 'NE', 'KS', 'TN', 'PR', 'AR', 'GU',
#        'WV', 'SC', 'ID', 'VI', 'ND', 'HI', 'VT', 'ME', 'NM', 'MP', 'AK',
#        'MT', 'GEORGIA', 'NEW YORK', 'TEXAS', 'CALIFORNIA', 'WASHINGTON',
#        'NEW JERSEY', 'ARIZONA', 'NORTH CAROLINA', 'WISCONSIN',
#        'LOUISIANA', 'MAINE', 'OHIO', 'MARYLAND', 'MASSACHUSETTS',
#        'MICHIGAN', 'ILLINOIS', 'PENNSYLVANIA', 'VERMONT', 'VIRGINIA',
#        'FLORIDA', 'MISSOURI', 'ARKANSAS', 'NEW HAMPSHIRE', 'INDIANA',
#        'OKLAHOMA', 'UTAH', 'CONNECTICUT', 'SOUTH DAKOTA', 'DELAWARE',
#        'ALABAMA', 'WEST VIRGINIA', 'NEBRASKA', 'OREGON', 'COLORADO',
#        'RHODE ISLAND', 'KANSAS', 'ALASKA', 'DISTRICT OF COLUMBIA',
# ...

# %%
a.employer_state.nunique()
# Out:
# 113

# %% [markdown]
# ### There are 58 unique employer states and most of them are mentioned as abbreviations for their respective               states names.

# %% [markdown]
# # `Feature 13`
# ## employer_yr_estab = 36.169269  % missing values

# %%
a.employer_yr_estab.nunique()
# Out:
# 262

# %%
a.employer_yr_estab.unique()
# Out:
# array([  nan, 1959., 1988., 1996., 2010., 2003., 2011., 1994., 1999.,
#        2006., 1955., 1993., 2005., 2000., 1934., 1973., 1998., 1948.,
#        1890., 1891., 1974., 1967., 2002., 2009., 2001., 1963., 2012.,
#        1828., 1990., 2004., 1997., 1856., 1977., 2007., 1982., 1989.,
#        1986., 1984., 2013., 1911., 1987., 1983., 1975., 1847., 1937.,
#        1885., 1981., 1966., 1939., 1944., 1980., 1962., 1926., 1978.,
#        1995., 1940., 1841., 1976., 2008., 1992., 1957., 1979., 1965.,
#        1970., 1922., 1950., 1991., 1968., 1945., 1850., 1909., 1886.,
#        1903., 1866., 1835., 1869., 1960., 1838., 1930., 1800., 1954.,
#        1985., 1862., 1946., 1931., 1947., 1897., 1920., 1932., 1935.,
#        1919., 1904., 1871., 1964., 1969., 1925., 1881., 1929., 1902.,
#        1888., 1949., 1872., 1854., 1889., 1936., 1896., 1901., 1895.,
#        1971., 1972., 1769., 1924., 1941., 1915., 1921., 1898., 1961.,
# ...

# %%
a.employer_yr_estab.value_counts().head(15)
# Out:
# 1994.0    15926
# 1999.0    10964
# 1998.0    10293
# 2004.0     8685
# 2000.0     7495
# 2006.0     7162
# 2007.0     6730
# 1996.0     6530
# 2008.0     6411
# 2010.0     6395
# 2005.0     6250
# 2011.0     6079
# 1997.0     6059
# 2009.0     5775
# 2003.0     5688
# Name: employer_yr_estab, dtype: int64

# %% [markdown]
# ### We are having total of 262 unique year of establishment of employer.

# %% [markdown]
# # `Feature 14`
# # foreign_worker_info_education = 36.143893 % null values

# %%
a.foreign_worker_info_education.unique()
# Out:
# array([nan, "Bachelor's", 'None', 'Doctorate', "Master's", 'Other',
#        'High School', "Associate's"], dtype=object)

# %%
a.foreign_worker_info_education.value_counts()
# Out:
# Master's       103662
# Bachelor's      87686
# None            18344
# Doctorate       12243
# Other           10245
# High School      4536
# Associate's      2337
# Name: foreign_worker_info_education, dtype: int64

# %%
sns.countplot(a.foreign_worker_info_education)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### There are 7 categories of foreign worker educational level
#      1.Master's
#      2.Bachelor's
#      3.None
#      4.Doctorate
#      5.Other
#      6.High School
#      7.Associate's
#
# ### Most of applicants are having either Master's or Bachelor's educational level.

# %% [markdown]
# # `Feature 15`
# ## foreign_worker_info_major = 41.396296 % null values

# %%
a.foreign_worker_info_major.unique()
# Out:
# array([nan, 'MECHANICAL ENGINEERING', 'MOLECULAR BIOLOGY', ...,
#        'INDUSTRIAL TRIBOLOGY & MAINTENANCE ENGINEERING',
#        'SECONDARY EDUCATION WITHOUT TEACHING LICENSURE',
#        'BUSINESS ADMINISTRATION AND LOGISTICS'], dtype=object)

# %%
a.foreign_worker_info_major.nunique()
# Out:
# 21851

# %%
a.foreign_worker_info_major.value_counts().head(16)
# Out:
# COMPUTER SCIENCE                       27218
# ELECTRICAL ENGINEERING                 13167
# COMPUTER ENGINEERING                   11862
# BUSINESS ADMINISTRATION                11394
# ENGINEERING                             7136
# MECHANICAL ENGINEERING                  6863
# ELECTRONIC ENGINEERING                  4953
# INFORMATION TECHNOLOGY                  4728
# COMPUTER APPLICATIONS                   4449
# MEDICINE                                4434
# COMPUTER INFORMATION SYSTEMS            4039
# COMPUTER SCIENCE AND ENGINEERING        3540
# ELECTRICAL AND COMPUTER ENGINEERING     3137
# ENGINEERING (ELECTRONIC)                2866
# ENGINEERING (COMPUTER)                  2597
# SOFTWARE ENGINEERING                    2208
# Name: foreign_worker_info_major, dtype: int64

# %%
a.foreign_worker_info_major.value_counts().head(15).plot(kind='bar')

# %% [markdown]
# ### There are 21851 categories of fields of foreign work and maximum are from Computer Science category.

# %% [markdown]
# # `Feature 16`
# ## job_experience  = 36.136413 % null values

# %%
a.job_experience.value_counts(normalize=True)
# Out:
# Y    0.556493
# N    0.443507
# Name: job_experience, dtype: float64

# %%
a.job_experience.value_counts().plot(kind="bar")

# %% [markdown]
# ### 56% of applicants are having work experience and 44% are not having any work experience.

# %% [markdown]
# # `Feature 17`
# ## job_title = 36.144961 % null values

# %%
a.job_title.unique()
# Out:
# array([nan, 'Senior Engineer', 'Catfish Processor', ...,
#        'Computer Systems Analyst, Data Integration',
#        'Senior .NET Developer(s)',
#        'Assistant Vice President, Divisional Business Information Security Officer'],
#       dtype=object)

# %%
a.job_title.nunique()
# Out:
# 59495

# %%
a.job_title.value_counts().head(25).plot(kind='bar',color='blue')

# %% [markdown]
# ### Most of the applicants are from Software engineers or computer related profession.

# %% [markdown]
# # `Feature 18`
# ## job_training =  36.137215 % null values

# %%
a.job_training.value_counts(normalize=True)
# Out:
# N    0.981429
# Y    0.018571
# Name: job_training, dtype: float64

# %%
a.job_training.value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ### 98% of applicants have job training.

# %% [markdown]
# # `Feature 19`
# ## job_work_state = 0.027513 % null values

# %%
a.job_work_state.nunique()
# Out:
# 113

# %%
a.job_work_state.unique()
# Out:
# array(['NY', 'MD', 'FL', 'TX', 'NJ', 'GA', 'IL', 'CA', 'KY', 'WY', 'OH',
#        'MS', 'MA', 'VA', 'ID', 'NC', 'MO', 'CT', 'AZ', 'WI', 'PA', 'WA',
#        'CO', 'MN', 'NV', 'UT', 'AL', 'OR', 'OK', 'LA', 'DC', 'MI', 'IA',
#        'RI', 'NH', 'IN', 'SD', 'NM', 'NE', 'KS', 'TN', 'PR', 'AR', 'GU',
#        'WV', 'SC', 'DE', 'VI', 'ND', 'HI', 'VT', 'ME', nan, 'AK', 'MT',
#        'GEORGIA', 'NEW YORK', 'CALIFORNIA', 'TEXAS', 'WASHINGTON',
#        'NEW JERSEY', 'ARIZONA', 'WISCONSIN', 'LOUISIANA', 'MAINE', 'OHIO',
#        'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'ILLINOIS',
#        'PENNSYLVANIA', 'UTAH', 'VIRGINIA', 'FLORIDA', 'ARKANSAS',
#        'NEW HAMPSHIRE', 'INDIANA', 'OKLAHOMA', 'CONNECTICUT',
#        'SOUTH DAKOTA', 'DELAWARE', 'ALABAMA', 'DISTRICT OF COLUMBIA',
#        'NORTH CAROLINA', 'WEST VIRGINIA', 'NEBRASKA', 'OREGON',
#        'COLORADO', 'RHODE ISLAND', 'MISSISSIPPI', 'KANSAS', 'ALASKA',
#        'MISSOURI', 'MINNESOTA', 'VERMONT', 'TENNESSEE', 'KENTUCKY',
# ...

# %% [markdown]
# ### There are 113 unique state where applicants worked.

# %% [markdown]
# # `Feature 20`
# ## pv_unit_of_pay_9089 = 2.685369 % null values

# %%
a.pv_unit_of_pay_9089.value_counts()
# Out:
# Year         336024
# yr            19757
# Hour           7446
# hr              726
# Week            179
# Month           121
# Bi-Weekly        23
# wk               21
# mth               7
# bi                5
# Name: pv_unit_of_pay_9089, dtype: int64

# %%
a.pv_unit_of_pay_9089.value_counts()
# Out:
# Year         336024
# yr            19757
# Hour           7446
# hr              726
# Week            179
# Month           121
# Bi-Weekly        23
# wk               21
# mth               7
# bi                5
# Name: pv_unit_of_pay_9089, dtype: int64

# %%
a.pv_unit_of_pay_9089.value_counts(normalize=True)
# Out:
# Year         0.922360
# yr           0.054231
# Hour         0.020439
# hr           0.001993
# Week         0.000491
# Month        0.000332
# Bi-Weekly    0.000063
# wk           0.000058
# mth          0.000019
# bi           0.000014
# Name: pv_unit_of_pay_9089, dtype: float64

# %% [markdown]
# ### Around 97% pay was given on the basis of year.

# %% [markdown]
# # `Feature 21`
# # previous_salary =  0.59194 % null values

# %%
a.previous_salary.unique()
# Out:
# array([ 75629.,  37024.,  47923., ...,  44237., 105818., 112354.])

# %%
a.previous_salary.nunique()
# Out:
# 24784

# %%
a.boxplot(column=['previous_salary']);    #  so many outliers in previous salary as it don't have a single scale

# %% [markdown]
# ### There is high trend of previous salary and unique salaries of applicants in our dataset.

# %% [markdown]
# # `Feature 22`
# ## level = 7.379755 % null values

# %%
a.level.value_counts()
# Out:
# Level II     119625
# Level IV      96550
# Level I       65687
# Level III     64873
# Name: level, dtype: int64

# %%
a.level.value_counts().plot(kind='bar')

# %% [markdown]
# ### There are 4 levels to which visas have been applied.

# %% [markdown]
# # `Feature 23`
# ## source_name = 0.560687 % null values

# %%
a.source_name.value_counts()
# Out:
# OES                   341918
# Other                  25851
# CBA                     3854
# Employer Conducted       539
# SCA                       77
# DBA                       24
# Name: source_name, dtype: int64

# %%
a.source_name.value_counts(normalize=True)
# Out:
# OES                   0.918485
# Other                 0.069443
# CBA                   0.010353
# Employer Conducted    0.001448
# SCA                   0.000207
# DBA                   0.000064
# Name: source_name, dtype: float64

# %%
a.source_name.value_counts(normalize=True).plot(kind='bar')

# %% [markdown]
# ### There are 6 sources through which visas have been applied or filed and mostly are through OES around  91%

# %% [markdown]
# # `Feature 24`
# ## sector =  65.523210 % null values

# %%
a.sector.value_counts()
# Most of them are having IT sector
# Out:
# IT                       52617
# Advanced Mfg             18749
# Other Economic Sector    15798
# Finance                   9224
# Educational Services      9130
# Health Care               6825
# Retail                    4408
# Aerospace                 4166
# Hospitality               1926
# Construction              1409
# Automotive                1163
# Energy                    1086
# Transportation             949
# Agribusiness               939
# Biotechnology              456
# Geospatial                 141
# Homeland Security           82
# Name: sector, dtype: int64

# %%
a.sector.value_counts().plot(kind='bar')

# %% [markdown]
# ### Most of them are from IT sector only.

# %% [markdown]
# # `Feature 25`
# ## wage_offer = 30.657759 % missing values

# %%
a.wage_offer.unique()
# Out:
# array([75629, 37024, 47923, ..., 117420.16, 77119.65, 65610], dtype=object)

# %%
a.wage_offer.nunique()
# Out:
# 28868

# %% [markdown]
# ### We are having different wage offers.

# %% [markdown]
# # `Feature 26`
# ## wage_unit_of_pay=   30.963613 % missing values

# %%
a.wage_unit_of_pay.unique()
# Out:
# array(['yr', 'hr', 'mth', 'wk', 'bi', nan, 'Year', 'Hour', 'Week',
#        'Month', 'Bi-Weekly'], dtype=object)

# %%
a.wage_unit_of_pay.value_counts()
# Out:
# Year         230591
# yr            19733
# Hour           7038
# hr              781
# Week            142
# Month            81
# wk               30
# mth              21
# Bi-Weekly        20
# bi                9
# Name: wage_unit_of_pay, dtype: int64

# %%
a.wage_unit_of_pay.value_counts(normalize=True)
# Out:
# Year         0.892221
# yr           0.076353
# Hour         0.027232
# hr           0.003022
# Week         0.000549
# Month        0.000313
# wk           0.000116
# mth          0.000081
# Bi-Weekly    0.000077
# bi           0.000035
# Name: wage_unit_of_pay, dtype: float64

# %%
a.wage_unit_of_pay.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Here also wage unit of pay was given on yearly basis only around 90%

# %% [markdown]
# # `BIVARIATE ANALYSIS`

# %% [markdown]
# ## Checking the correlation between dependent and independent variable by crosstab as we are having 23 categorical columns and 3 numerical columns

# %%
a.groupby(['application_type', 'case_status'])['case_status'].count().unstack()
# Out:
# case_status       Certified  Certified-Expired  Denied  Withdrawn
# application_type
# MAILEDIN                184                321    1508        116
# ONLINE                48973              47968    8675       6948
# PERM                  11807               4727    2685       1357

# %% [markdown]
# ### combining class of admission with their respective categories

# %%
a.class_of_admission.replace('J-1','J',inplace=True)
a.class_of_admission.replace('J-2','J',inplace=True)
a.class_of_admission.replace('B-2','B',inplace=True)
a.class_of_admission.replace('B-1','B',inplace=True)
a.class_of_admission.replace('H-2B','H-1B',inplace=True)
a.class_of_admission.replace('H-2A','H-1B',inplace=True)
a.class_of_admission.replace('H-1A','H-1B',inplace=True)
a.class_of_admission.replace('H-1B1','H-1B',inplace=True)
a.class_of_admission.replace('AOS/H-1B','H-1B',inplace=True)
a.class_of_admission.replace('H-4','H-1B',inplace=True)
a.class_of_admission.replace('H-3','H-1B',inplace=True)
a.class_of_admission.replace('H-1C','H-1B',inplace=True)
a.class_of_admission.replace('H1B','H-1B',inplace=True)
a.class_of_admission.replace('L-1','L',inplace=True)
a.class_of_admission.replace('L-2','L',inplace=True)
a.class_of_admission.replace('Parol','Parole',inplace=True)
a.class_of_admission.replace('Parolee','Parole',inplace=True)
a.class_of_admission.replace('E-1','E',inplace=True)
a.class_of_admission.replace('E-2','E',inplace=True)
a.class_of_admission.replace('E-3','E',inplace=True)
a.class_of_admission.replace('F-1','F',inplace=True)
a.class_of_admission.replace('F-2','F',inplace=True)
a.class_of_admission.replace('G-1','G',inplace=True)
a.class_of_admission.replace('G-4','G',inplace=True)
a.class_of_admission.replace('G-5','G',inplace=True)
a.class_of_admission.replace('M-1','M',inplace=True)
a.class_of_admission.replace('M-2','M',inplace=True)
a.class_of_admission.replace('O-1','O',inplace=True)
a.class_of_admission.replace('O-2','O',inplace=True)
a.class_of_admission.replace('O-3','O',inplace=True)
a.class_of_admission.replace('P-1','P',inplace=True)
a.class_of_admission.replace('P-2','P',inplace=True)
a.class_of_admission.replace('P-3','P',inplace=True)
a.class_of_admission.replace('P-4','P',inplace=True)
a.class_of_admission.replace('R-1','R',inplace=True)
a.class_of_admission.replace('R-2','R',inplace=True)
a.class_of_admission.replace('C-1','C',inplace=True)
a.class_of_admission.replace('C-2','C',inplace=True)
a.class_of_admission.replace('C-3','C',inplace=True)
a.class_of_admission.replace('A1/A2','A',inplace=True)
a.class_of_admission.replace('A-2','A',inplace=True)
a.class_of_admission.replace('A-3','P',inplace=True)

# %%
pd.crosstab([a.application_type, a.class_of_admission],a.case_status, margins=True)
# Out:
# case_status                          Certified  Certified-Expired  Denied  \
# application_type class_of_admission
# MAILEDIN         A                           0                  0       1
#                  B                          16                 38     178
#                  C                           2                  1       4
#                  E                           3                  8      33
#                  EWI                        45                 83     163
#                  F                          10                 18      89
#                  G                           1                  1       4
#                  H-1B                       61                 87     401
#                  I                           0                  0       1
#                  J                           2                  0      12
#                  K-1                         0                  0       0
# ...

# %%
sns.countplot(x="application_type",hue="case_status",data=a)

# %% [markdown]
# ## applicants having certified are mostly through online application type

# %%
pd.crosstab(a.application_type,a.case_status,margins=True,normalize=False)
# Out:
# case_status       Certified  Certified-Expired  Denied  Withdrawn     All
# application_type
# MAILEDIN                184                321    1508        116    2129
# ONLINE                48973              47968    8675       6948  112564
# PERM                  11807               4727    2685       1357   20576
# All                   60964              53016   12868       8421  135269

# %% [markdown]
# ### Most of Online application type was among certified and certified-expired category and we can see very less number of certfied cases in Mailed in category

# %% [markdown]
# ## Combining names of countries with their respective abbreviations

# %%
state_abbrevs = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    'Northern Mariana Islands':'MP', 
    'Palau': 'PW', 
    'Puerto Rico': 'PR', 
    'Virgin Islands': 'VI', 
    'District of Columbia': 'DC',
    'MARSHALL ISLANDS':'MH'
}

# %%
us_state_abbrev = {k.upper(): v for k, v in state_abbrevs.items()}
a['agent_state'].replace(us_state_abbrev, inplace=True)
a.agent_state = a.agent_state.astype(str)

# %%
pd.crosstab(a.agent_state,a.case_status)
# Out:
# case_status  Certified  Certified-Expired  Denied  Withdrawn
# agent_state
# AK                   7                  6       1          0
# AL                 154                102      16         20
# AR                  68                 67      21         10
# AZ                3080               1737     409        373
# CA               27375              23022    2538       2259
# CO                 970                784     134        122
# CT                 816                609      97         95
# DC                2057               1638     140        165
# DE                  20                 13       0          0
# FL                2818               1889     542        221
# GA                6276               4737     692        809
# GU                  60                 64      17          4
# GUAM                41                 11       4          1
# HI                  46                 26      14          3
# ...

# %% [markdown]
# ### After imputing abbreviations of their respective countries name we have unique values for agent states and we have maximum certified cases from California

# %%
pd.crosstab(a.class_of_admission,a.case_status)
# Out:
# case_status         Certified  Certified-Expired  Denied  Withdrawn
# class_of_admission
# A                          66                 52      31          6
# AOS                         0                  1       0          0
# B                        1532               1078    1145        198
# C                          17                 10      17          3
# D-1                         1                  2       3          0
# E                        2692               1934     665        373
# EWI                       512                552     814         77
# F                        7839               5478    1556       1033
# G                          84                 65      23         11
# H-1B                   140141             117454   14718      12653
# I                          37                 29      11          5
# J                         544                343     113         64
# ...

# %% [markdown]
# ### Mostly H1_B visa applications was filed and cerified.

# %%
pd.crosstab(a.employer_state,a.case_status)
# Out:
# case_status           Certified  Certified-Expired  Denied  Withdrawn
# employer_state
# AK                           29                 16       3          5
# AL                          432                296      70         25
# ALABAMA                     653                526     152         76
# ALASKA                       22                 21      11          2
# AR                          445                250      84        157
# ARIZONA                     784                741     157        119
# ARKANSAS                    324                336      73         28
# AZ                          744                439     142         75
# BC                            1                  0       0          0
# BRITISH COLUMBIA              2                  1       0          0
# CA                        23602              15299    1967       1498
# CALIFORNIA                23216              21910    3186       2815
# ...

# %%
us_state_abbrev = {k.upper(): v for k, v in state_abbrevs.items()}
a['employer_state'].replace(us_state_abbrev, inplace=True)
a.employer_state = a.agent_state.astype(str)

# %%
pd.crosstab(a.employer_state,a.case_status)
# Out:
# case_status     Certified  Certified-Expired  Denied  Withdrawn
# employer_state
# AK                      7                  6       1          0
# AL                    154                102      16         20
# AR                     68                 67      21         10
# AZ                   3080               1737     409        373
# CA                  27375              23022    2538       2259
# CO                    970                784     134        122
# CT                    816                609      97         95
# DC                   2057               1638     140        165
# DE                     20                 13       0          0
# FL                   2818               1889     542        221
# GA                   6276               4737     692        809
# GU                     60                 64      17          4
# GUAM                   41                 11       4          1
# ...

# %% [markdown]
# ### After imputitng abbreviation of employer state again we can see California have the maximum no of certified cases

# %%
pd.crosstab([a.foreign_worker_info_education, a.class_of_admission],a.case_status, margins=True)
# Out:
# case_status                                       Certified  \
# foreign_worker_info_education class_of_admission
# Associate's                   A                           1
#                               B                          51
#                               C                           0
#                               E                         105
#                               EWI                         1
#                               F                         178
#                               G                           1
#                               H-1B                      352
#                               I                           0
#                               J                           6
#                               L                          75
#                               Not in USA                106
#                               O                           6
#                               P                           5
# ...

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="foreign_worker_info_education",hue="case_status",data=a)

# %% [markdown]
# ### Mostly applicants having Master and bachelor degree visasa applications have been certified.

# %%
pd.crosstab(a.job_experience,a.case_status)
# Out:
# case_status     Certified  Certified-Expired  Denied  Withdrawn
# job_experience
# N                   53583              40104    6812       5535
# Y                   67385              55465    5961       4236

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="job_experience",hue="case_status",data=a)

# %% [markdown]
# ### Applicants having job experience have the maximum no of count for visa to be certified.

# %%
pd.crosstab(a.job_training,a.case_status,margins=False)
# Out:
# case_status   Certified  Certified-Expired  Denied  Withdrawn
# job_training
# N                119106              93801   12148       9583
# Y                  1862               1769     621        188

# %%
pd.crosstab([a.job_training, a.job_experience],a.case_status, margins=True)
# Out:
# case_status                  Certified  Certified-Expired  Denied  Withdrawn  \
# job_training job_experience
# N            N                   51874              38445    6604       5376
#              Y                   67231              55355    5540       4207
# Y            N                    1709               1659     205        159
#              Y                     153                110     413         29
# All                             120967              95569   12762       9771
#
# case_status                     All
# job_training job_experience
# N            N               102299
#              Y               132333
# Y            N                 3732
#              Y                  705
# All                          239069

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="job_training",hue="case_status",data=a)

# %% [markdown]
# ### Mostly applications are cerified for those not having job training

# %%
pd.crosstab(a.job_work_state,a.case_status)
# Out:
# case_status                     Certified  Certified-Expired  Denied  \
# job_work_state
# AK                                     31                 21       3
# AL                                    441                309      69
# ALABAMA                               652                549     152
# ALASKA                                 25                 24      13
# AR                                    392                137      76
# ARIZONA                              1107                996     207
# ARKANSAS                              199                239      69
# AZ                                   1085                573     154
# CA                                  21980              14373    1811
# CALIFORNIA                          21259              20507    3389
# CO                                    748                480     104
# COLORADO                              719                674     131
# ...

# %%
us_state_abbrev = {k.upper(): v for k, v in state_abbrevs.items()}
a['job_work_state'].replace(us_state_abbrev, inplace=True)
a.job_work_state = a.agent_state.astype(str)

# %%
pd.crosstab(a.job_work_state,a.case_status)
# Out:
# case_status     Certified  Certified-Expired  Denied  Withdrawn
# job_work_state
# AK                      7                  6       1          0
# AL                    154                102      16         20
# AR                     68                 67      21         10
# AZ                   3080               1737     409        373
# CA                  27375              23022    2538       2259
# CO                    970                784     134        122
# CT                    816                609      97         95
# DC                   2057               1638     140        165
# DE                     20                 13       0          0
# FL                   2818               1889     542        221
# GA                   6276               4737     692        809
# GU                     60                 64      17          4
# GUAM                   41                 11       4          1
# ...

# %% [markdown]
# ### California have the maximum no of cerified cases

# %% [markdown]
# ## Combining short abbreviations

# %%
a.pv_unit_of_pay_9089.replace('yr','Year',inplace=True)
a.pv_unit_of_pay_9089.replace('hr','Hour',inplace=True)
a.pv_unit_of_pay_9089.replace('bi','Bi-Weekly',inplace=True)
a.pv_unit_of_pay_9089.replace('mth','Month',inplace=True)
a.pv_unit_of_pay_9089.replace('wk','Week',inplace=True)

# %%
pd.crosstab(a.pv_unit_of_pay_9089,a.case_status)
# Out:
# case_status          Certified  Certified-Expired  Denied  Withdrawn
# pv_unit_of_pay_9089
# Bi-Weekly                    4                  1      22          1
# Hour                      2884               2102    2485        701
# Month                       31                 37      51          9
# Week                        48                 42      98         12
# Year                    170689             146126   21872      17094

# %%
pd.crosstab([a.pv_unit_of_pay_9089, a.level],a.case_status, margins=True)
# Out:
# case_status                    Certified  Certified-Expired  Denied  \
# pv_unit_of_pay_9089 level
# Bi-Weekly           Level I            0                  0       4
#                     Level II           1                  0       1
#                     Level III          1                  1       2
#                     Level IV           0                  0       3
# Hour                Level I         1548                997     742
#                     Level II         654                503     430
#                     Level III        358                283     269
#                     Level IV         235                209     221
# Month               Level I           11                 10      16
#                     Level II           8                 11       3
#                     Level III          3                  3       5
#                     Level IV           3                  3       9
# ...

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="level",hue="case_status",data=a)

# %% [markdown]
# ### Maximum pay was given on yearly basis having Level II

# %%
pd.crosstab(a.level,a.case_status)
# Out:
# case_status  Certified  Certified-Expired  Denied  Withdrawn
# level
# Level I          31103              24140    5966       4478
# Level II         58946              48455    6791       5433
# Level III        32011              25633    4037       3192
# Level IV         47316              40131    5054       4049

# %% [markdown]
# ### Level II category applicants have maximum cerified status of visa.

# %%
pd.crosstab(a.source_name,a.case_status)
# Out:
# case_status         Certified  Certified-Expired  Denied  Withdrawn
# source_name
# CBA                      1563               1319     756        216
# DBA                         0                  0      24          0
# Employer Conducted        117                 95     301         26
# OES                    167192             136621   21233      16872
# Other                   13020              10531    1240       1060
# SCA                        14                  8      47          8

# %%
pd.crosstab([a.source_name, a.level],a.case_status, margins=True)
# Out:
# case_status                   Certified  Certified-Expired  Denied  Withdrawn  \
# source_name        level
# CBA                Level I          314                239     122         51
#                    Level II           7                  9       9          0
#                    Level III          2                  3       3          0
#                    Level IV           7                  2       3          0
# DBA                Level I            0                  0       7          0
#                    Level II           0                  0       3          0
# Employer Conducted Level I           17                  7      57          4
#                    Level II          15                  7      43          8
#                    Level III          4                  4      27          2
#                    Level IV          11                  8      27          0
# OES                Level I        30400              23562    5580       4350
# ...

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="source_name",hue="case_status",data=a)

# %% [markdown]
# ### Occupational Employment Statistics(OES) have the maximum certified visas.

# %%
pd.crosstab(a.sector,a.case_status)
# Out:
# case_status            Certified  Certified-Expired  Denied  Withdrawn
# sector
# Advanced Mfg                9091               7414    1096       1148
# Aerospace                   1945               1729     243        249
# Agribusiness                 317                225     242        155
# Automotive                   459                474     151         79
# Biotechnology                215                209      12         20
# Construction                 476                475     364         94
# Educational Services        4031               3593     937        569
# Energy                       536                441      44         65
# Finance                     4494               3795     397        538
# Geospatial                    72                 57       8          4
# Health Care                 3281               2561     565        418
# Homeland Security             28                 36      14          4
# ...

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="sector",hue="case_status",data=a)

# %% [markdown]
# ### IT sector have the maximum cerified visas

# %%
a.wage_unit_of_pay.replace('hr','Hour',inplace=True)
a.wage_unit_of_pay.replace('bi','Bi-Weekly',inplace=True)
a.wage_unit_of_pay.replace('mth','Month',inplace=True)
a.wage_unit_of_pay.replace('wk','Week',inplace=True)
a.wage_unit_of_pay.replace('yr','Year',inplace=True)

# %%
pd.crosstab(a.wage_unit_of_pay,a.case_status)
# Out:
# case_status       Certified  Certified-Expired  Denied  Withdrawn
# wage_unit_of_pay
# Bi-Weekly                 6                  3      19          1
# Hour                   3351               1953    1796        719
# Month                    34                 22      45          1
# Week                     42                 32      89          9
# Year                 128685              98017   13305      10317

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,9))
sns.countplot(x="wage_unit_of_pay",hue="case_status",data=a)

# %% [markdown]
# ### wages given on yearly basis got the maximum certified cases.

# %% [markdown]
# # `MULTIVARIATE ANALYSIS`

# %%
a.corr()   # checking correlation between numerical columns
# Out:
#                         employer_num_employees  employer_yr_estab  \
# employer_num_employees                1.000000          -0.027993
# employer_yr_estab                    -0.027993           1.000000
# previous_salary                       0.008035           0.024300
#
#                         previous_salary
# employer_num_employees         0.008035
# employer_yr_estab              0.024300
# previous_salary                1.000000

# %% [markdown]
# ## Checking the correlation between numerical columns in our dataset using heat map

# %%
plt.figure(figsize=(12,8))
sns.heatmap(a.corr(),annot=True)
plt.show()

# %% [markdown]
# ## Checking the correlation between numerical columns in our dataset using Pairplot

# %%
plt.figure(figsize=(12,9))
sns.pairplot(a,hue="case_status")
plt.show()
